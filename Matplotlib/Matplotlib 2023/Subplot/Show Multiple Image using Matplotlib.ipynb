# %% [markdown]
# matplotlib work with image: https://matplotlib.org/stable/tutorials/introductory/images.html

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import image
import PIL
import os

# %%
x = plt.imread(fname="img/10001.jpg")
plt.imshow(X=x,)
plt.show()

# %%
x
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
list(enumerate(os.listdir(path=r"C:\Users\alami\Downloads\myproject\Fasion\img")))
# Out:
# [(0, '10000.jpg'),
#  (1, '10001.jpg'),
#  (2, '10008.jpg'),
#  (3, '10009.jpg'),
#  (4, '10035.jpg'),
#  (5, '10047.jpg'),
#  (6, '10064.jpg'),
#  (7, '10098.jpg'),
#  (8, '10117.jpg'),
#  (9, '10136.jpg'),
#  (10, '10184.jpg'),
#  (11, '10197.jpg'),
#  (12, '10324.jpg'),
#  (13, '10331.jpg')]

# %%
plt.figure(figsize=(10,20))

for i, file in enumerate(os.listdir(path=r"C:\Users\alami\Downloads\myproject\Fasion\img")):
    plt.subplot(5, 3, i+1)
    img = plt.imread(fname=r"img\\" + file)
    plt.imshow(img)
    plt.tight_layout()
    plt.xticks(rotation=45)
