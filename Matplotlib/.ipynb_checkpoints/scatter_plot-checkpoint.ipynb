# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.randint(1,40,(80))
y = np.random.randint(1,17,(80))

# %%
print(x)
print(y)
# Out:
# [ 4 25 30 35 21 25 36 31 10 34 22  1  3 32 14 18 22 21 21  8 10 31 29 19
#  39 39  3 37 25 32 10 13 33 34 32 36 30 22 34 25 11 17 34 29 25 34 31 16
#   5 32 39 37  4  8 33 38 38 15 12  7 29 25 18 34 30 33  1  7 13  8 20  2
#   3 35 18 11  2 15 19 19]
# [13 14  9 12  4  3  7  7  2  4 15 15  2  7 10 15  3 11 13  5 16 15  7 15
#  11  9 14  7 10 12  4  3 16 13  4  5 13  4 14 15 13  9  5  1  7 15 12 13
#   9 10  6  1 16  9 13  4  8  3  8  9  2 10 14  9 14  7  4  7 15 11 16  2
#   9 16  1  2 16  1 16 13]

# %%
plt.figure(figsize=(10,8))
plt.scatter(x,y,color="g",marker="*",s=60,alpha=0.5,linewidths=5,edgecolors='c')
plt.title("Scatter plot")
plt.xlabel("alamin")
plt.ylabel("bhuyan")
# Out:
# Text(0, 0.5, 'bhuyan')
