# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
dataset = pd.read_csv("LabelEncoding.csv")
dataset
# Out:
#         car model  mileage  age  sell price
# 0          BMW X5    69000    6       18000
# 1          BMW X5    35000    3       34000
# 2          BMW X5    57000    5       26100
# 3          BMW X5    22500    2       40000
# 4          BMW X5    46000    4       31500
# 5            Audi    59000    5       29400
# 6            Audi    52000    5       32000
# 7            Audi    72000    6       19300
# 8            Audi    91000    8       12000
# 9   Mercedez Benz    67000    6       22000
# 10  Mercedez Benz    83000    7       20000
# 11  Mercedez Benz    79000    7       21000
# 12  Mercedez Benz    59000    5       33000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   car model   13 non-null     object
#  1   mileage     13 non-null     int64
#  2   age         13 non-null     int64
#  3   sell price  13 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 544.0+ bytes

# %% [markdown]
# ## data preprocessing

# %%
dummies = pd.get_dummies(dataset['car model'])
dummies
# Out:
#     Audi  BMW X5  Mercedez Benz
# 0      0       1              0
# 1      0       1              0
# 2      0       1              0
# 3      0       1              0
# 4      0       1              0
# 5      1       0              0
# 6      1       0              0
# 7      1       0              0
# 8      1       0              0
# 9      0       0              1
# 10     0       0              1
# 11     0       0              1
# 12     0       0              1

# %%
dataset = pd.concat([dataset,dummies],axis='columns')
dataset
# Out:
#         car model  mileage  age  sell price  Audi  BMW X5  Mercedez Benz
# 0          BMW X5    69000    6       18000     0       1              0
# 1          BMW X5    35000    3       34000     0       1              0
# 2          BMW X5    57000    5       26100     0       1              0
# 3          BMW X5    22500    2       40000     0       1              0
# 4          BMW X5    46000    4       31500     0       1              0
# 5            Audi    59000    5       29400     1       0              0
# 6            Audi    52000    5       32000     1       0              0
# 7            Audi    72000    6       19300     1       0              0
# 8            Audi    91000    8       12000     1       0              0
# 9   Mercedez Benz    67000    6       22000     0       0              1
# 10  Mercedez Benz    83000    7       20000     0       0              1
# 11  Mercedez Benz    79000    7       21000     0       0              1
# 12  Mercedez Benz    59000    5       33000     0       0              1

# %%
dataset = dataset.drop(['car model'],axis='columns')

# %%
dataset
# Out:
#     mileage  age  sell price  Audi  BMW X5  Mercedez Benz
# 0     69000    6       18000     0       1              0
# 1     35000    3       34000     0       1              0
# 2     57000    5       26100     0       1              0
# 3     22500    2       40000     0       1              0
# 4     46000    4       31500     0       1              0
# 5     59000    5       29400     1       0              0
# 6     52000    5       32000     1       0              0
# 7     72000    6       19300     1       0              0
# 8     91000    8       12000     1       0              0
# 9     67000    6       22000     0       0              1
# 10    83000    7       20000     0       0              1
# 11    79000    7       21000     0       0              1
# 12    59000    5       33000     0       0              1

# %% [markdown]
# ## split featurs and level

# %%
level = dataset['sell price']
featurs = dataset.drop(['sell price'],axis='columns')

# %%
level
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: sell price, dtype: int64

# %%
featurs
# Out:
#     mileage  age  Audi  BMW X5  Mercedez Benz
# 0     69000    6     0       1              0
# 1     35000    3     0       1              0
# 2     57000    5     0       1              0
# 3     22500    2     0       1              0
# 4     46000    4     0       1              0
# 5     59000    5     1       0              0
# 6     52000    5     1       0              0
# 7     72000    6     1       0              0
# 8     91000    8     1       0              0
# 9     67000    6     0       0              1
# 10    83000    7     0       0              1
# 11    79000    7     0       0              1
# 12    59000    5     0       0              1

# %% [markdown]
# ## model selection

# %%
xtrain,xtest,ytrain,ytest = train_test_split(featurs,level,test_size=0.2,random_state=1)

# %%
xtrain
# Out:
#     mileage  age  Audi  BMW X5  Mercedez Benz
# 10    83000    7     0       0              1
# 1     35000    3     0       1              0
# 6     52000    5     1       0              0
# 0     69000    6     0       1              0
# 7     72000    6     1       0              0
# 12    59000    5     0       0              1
# 9     67000    6     0       0              1
# 8     91000    8     1       0              0
# 11    79000    7     0       0              1
# 5     59000    5     1       0              0

# %%
ytrain
# Out:
# 10    20000
# 1     34000
# 6     32000
# 0     18000
# 7     19300
# 12    33000
# 9     22000
# 8     12000
# 11    21000
# 5     29400
# Name: sell price, dtype: int64

# %%
model = LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-3.55330204e-01, -1.73845122e+03,  1.04745223e+03, -4.59817298e+03,
#         3.55072075e+03])

# %%
model.intercept_
# Out:
# 56898.37412001342

# %%
model.score(xtest,ytest)
# Out:
# 0.8526576494631262

# %%
y_predict=model.predict(xtest)

# %%
y_predict
# Out:
# array([23354.12336574, 40828.36909152, 29001.20683875])

# %%
mean_s_error = mean_squared_error(y_predict,ytest)

# %%
mean_s_error
# Out:
# 4823333.701685976

# %%
mean_squarde_error2 = mean_squared_error(ytest,y_predict)
mean_squarde_error2
# Out:
# 4823333.701685976
