# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
dataset = pd.read_csv("CarPrice_Assignment.csv")

# %%
dataset.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
dataset.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
dataset.isnull().sum().any()
# Out:
# False

# %% [markdown]
# ## data visualization

# %%
plt.figure(figsize=(25,25))
sb.countplot(dataset["CarName"])
# Out:
# c:\users\alami\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CarName', ylabel='count'>

# %%
plt.figure(figsize=(25,25))
sb.countplot(dataset["fueltype"])
# Out:
# c:\users\alami\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fueltype', ylabel='count'>

# %% [markdown]
# ## encoding

# %%
encoder = LabelEncoder()

# %%
x = dataset.apply(encoder.fit_transform)
x
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0         0          5        2         1           0           1        0
# 1         1          5        3         1           0           1        0
# 2         2          3        1         1           0           1        2
# 3         3          4        4         1           0           0        3
# 4         4          4        5         1           0           0        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 200     200          1      139         1           0           0        3
# 201     201          1      138         1           1           0        3
# 202     202          1      140         1           0           0        3
# 203     203          1      142         0           1           0        3
# 204     204          1      143         1           1           0        3
#
# ...

# %% [markdown]
# ## co-relation display

# %%
plt.figure(figsize=(20,20))
sb.heatmap(dataset.corr(), annot=True, cmap="RdYlGn")
# Out:
# <AxesSubplot:>

# %%
featurs = x.iloc[:,1:-1].values
featurs
# Out:
# array([[  5,   2,   1, ...,  10,   8,  10],
#        [  5,   3,   1, ...,  10,   8,  10],
#        [  3,   1,   1, ...,  10,   6,   9],
#        ...,
#        [  1, 140,   1, ...,  16,   5,   6],
#        [  1, 142,   0, ...,   8,  13,  10],
#        [  1, 143,   1, ...,  15,   6,   8]], dtype=int64)

# %%
featurs1 = x.iloc[:,1:-1]
featurs1
# Out:
#      symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0            5        2         1           0           1        0
# 1            5        3         1           0           1        0
# 2            3        1         1           0           1        2
# 3            4        4         1           0           0        3
# 4            4        5         1           0           0        3
# ..         ...      ...       ...         ...         ...      ...
# 200          1      139         1           0           0        3
# 201          1      138         1           1           0        3
# 202          1      140         1           0           0        3
# 203          1      142         0           1           0        3
# 204          1      143         1           1           0        3
#
#      drivewheel  enginelocation  wheelbase  carlength  ...  cylindernumber  \
# 0             2               0          2         22  ...               2
# ...

# %%
label = x.iloc[:,-1]
label
# Out:
# 0      118
# 1      137
# 2      137
# 3      123
# 4      148
#       ...
# 200    143
# 201    161
# 202    165
# 203    167
# 204    168
# Name: price, Length: 205, dtype: int64

# %%
xtrain,xtest,ytrain,ytest = train_test_split(featurs1,label,test_size =.25,random_state=7)

# %%
xtrain
# Out:
#      symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 120          3       92         1           0           0        2
# 80           5       66         1           1           1        2
# 133          4      103         1           0           0        3
# 28           1       33         1           0           0        4
# 18           4       24         1           0           1        2
# ..         ...      ...       ...         ...         ...      ...
# 151          3      120         1           0           1        2
# 67           1       19         0           1           0        3
# 25           3       29         1           0           0        3
# 196          0      140         1           0           0        3
# 175          1      120         1           0           0        2
#
#      drivewheel  enginelocation  wheelbase  carlength  ...  cylindernumber  \
# 120           1               0          8          6  ...               2
# ...

# %%
ytrain
# Out:
# 120     10
# 80      81
# 133    107
# 28      67
# 18       1
#       ...
# 151     12
# 67     171
# 25      20
# 196    134
# 175     84
# Name: price, Length: 153, dtype: int64

# %% [markdown]
# ## featurs scalling

# %%
sc_x = StandardScaler()

# %%
xtrain = sc_x.fit_transform(xtrain)
# xtest = sc_x.fit_transform(xtest)
xtest = sc_x.transform(xtest)

# %%
xtrain
# Out:
# array([[ 0.13910505,  0.38747201,  0.31736324, ...,  0.91773696,
#          0.96894132,  1.13564722],
#        [ 1.71562895, -0.24294257,  0.31736324, ...,  0.91773696,
#         -0.3076832 , -0.01178502],
#        [ 0.927367  ,  0.65418587,  0.31736324, ...,  0.33104996,
#         -0.62683933, -0.3396228 ],
#        ...,
#        [ 0.13910505, -1.14007101,  0.31736324, ...,  0.91773696,
#          0.96894132,  1.13564722],
#        [-2.2256808 ,  1.5513143 ,  0.31736324, ...,  0.72217463,
#         -0.14810513, -0.3396228 ],
#        [-1.43741885,  1.06638001,  0.31736324, ..., -2.01569802,
#          0.33062906,  0.31605276]])

# %%
xtest
# Out:
# array([[-1.60709722, -0.3703193 ,  0.36115756, ...,  0.74391639,
#         -0.43928652, -0.20770325],
#        [-0.74556056,  0.61138991,  0.36115756, ..., -0.0035938 ,
#          0.05372569,  0.15231571],
#        [ 0.11597609, -1.35202851,  0.36115756, ...,  0.74391639,
#          0.8754127 ,  1.05236311],
#        ...,
#        [-0.74556056,  0.98897037, -2.76887462, ..., -1.31173664,
#          1.3684249 ,  0.69234415],
#        [ 0.11597609, -1.04996414,  0.36115756, ...,  0.74391639,
#          2.02577451,  1.59239155],
#        [-0.74556056, -1.72960898,  0.36115756, ..., -1.87236928,
#         -0.76796132, -0.56772221]])

# %% [markdown]
# # model selection

# %%
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.score(xtest,ytest)
# Out:
# 0.7471643402969141

# %%
y_predict = model.predict(xtest)

# %%
y_predict
# Out:
# array([110.2132606 ,  88.9356665 ,  25.28290129, 119.45244948,
#        120.32104697, 160.21885146, 137.57912589,  25.24856614,
#        114.81331316, 102.17075635,  32.33472842,  38.03534025,
#         30.63086428, 126.81798312,  36.35231263,  32.45048465,
#         36.18053684, 166.90260306,  36.88331609, 129.03752648,
#         60.83405851,  52.19851832, 109.89765045, 218.83324848,
#        109.5942904 , 149.00497314,  92.19001716, 141.0114505 ,
#        108.63087554,  64.73702016, 110.09729709, 160.91725252,
#         78.92205552,  74.03182133, 170.03132269, 100.29754766,
#        194.01441258,  88.48953542, 131.40223711,  48.25399583,
#         27.39317157, 173.74111125,  87.2285187 , 161.88061505,
#         65.38221643,  77.41004995,  26.78601123,  39.21155416,
#         17.00997548,  45.94707929,  22.74297605, 137.96321921])
