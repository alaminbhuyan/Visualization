# %%
import pandas as pd

# %% [markdown]
# ## Working with json

# %%
json_data = pd.read_json("Dataset/train.json")

json_data.head(10)
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# 5   6602     jamaican  [plain flour, sugar, butter, eggs, fresh ginge...
# 6  42779      spanish  [olive oil, salt, medium shrimp, pepper, garli...
# 7   3735      italian  [sugar, pistachio nuts, white almond bark, flo...
# 8  16903      mexican  [olive oil, purple onion, fresh pineapple, por...
# 9  12734      italian  [chopped tomatoes, fresh basil, garlic, extra-...

# %% [markdown]
# ## It also work api url. Here I just use fake api posts json data
#
# https://jsonplaceholder.typicode.com/

# %%
json_data2 = pd.read_json("https://jsonplaceholder.typicode.com/posts")

json_data2.head(10)
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
# 5       1   6                 dolorem eum magni eos aperiam quia
# 6       1   7                               magnam facilis autem
# 7       1   8                           dolorem dolore est ipsam
# 8       1   9  nesciunt iure omnis dolorem tempora et accusan...
# 9       1  10                        optio molestias id quia eum
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# ...

# %% [markdown]
# ## Working with SQL data
#
# https://www.kaggle.com/datasets/busielmorley/worldcities-pop-lang-rank-sql-create-tbls?select=world.sql

# %%
# Before working install this package

# !pip install mysql.connector

# %%
import mysql.connector

# %%
# Create a connection with the database

conn = mysql.connector.connect(host='localhost', user='root', password='', database='world')

# %%
# You can do all sql query 


my_query = "SELECT * FROM country" 


sql_data = pd.read_sql_query(sql=my_query, con=conn)

sql_data.head()
# Out:
# C:\Users\alami\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
# 2  AGO       Angola         Africa             Central Africa    1246700.0
# 3  AIA     Anguilla  North America                  Caribbean         96.0
# 4  ALB      Albania         Europe            Southern Europe      28748.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
# ...

# %%
my_query = "SELECT * FROM countrylanguage" 

sql_data2 = pd.read_sql_query(sql=my_query, con=conn)

sql_data2.head()
# Out:
# C:\Users\alami\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   CountryCode    Language IsOfficial  Percentage
# 0         ABW       Dutch          T         5.3
# 1         ABW     English          F         9.5
# 2         ABW  Papiamento          F        76.7
# 3         ABW     Spanish          F         7.4
# 4         AFG     Balochi          F         0.9

# %%
my_query = "SELECT * FROM city" 

sql_data2 = pd.read_sql_query(sql=my_query, con=conn)

sql_data2.head()
# Out:
# C:\Users\alami\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    ID            Name CountryCode       District  Population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200

# %% [markdown]
# ### Using read_sql() method

# %%
my_query = "SELECT * FROM country" 


sql_data3 = pd.read_sql(sql=my_query, con=conn)

sql_data3.head()
# Out:
# C:\Users\alami\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
# 2  AGO       Angola         Africa             Central Africa    1246700.0
# 3  AIA     Anguilla  North America                  Caribbean         96.0
# 4  ALB      Albania         Europe            Southern Europe      28748.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
# ...
